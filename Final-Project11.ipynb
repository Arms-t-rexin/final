# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Assignment: Notebook for Peer Assignment
#
# Estimated time needed: 45 minutes

# %% [markdown]
# # Assignment Scenario
#
# Congratulations! You have just been hired by a US Venture Capital firm as a data analyst.
#
# The company is considering foreign grain markets to help meet its supply chain requirements for its recent investments in the microbrewery and microdistillery industry, which is involved with the production and distribution of craft beers and spirits.
#
# Your first task is to provide a high level analysis of crop production in Canada. Your stakeholders want to understand the current and historical performance of certain crop types in terms of supply and price volatility. For now they are mainly interested in a macro-view of Canada's crop farming industry, and how it relates to the relative value of the Canadian and US dollars.

# %% [markdown]
# # Introduction
#
# Using this R notebook you will:
#
# 1.  Understand four datasets
# 2.  Load the datasets into four separate tables in a Db2 database
# 3.  Execute SQL queries unsing the RODBC R package to answer assignment questions
#
# You have already encountered two of these datasets in the previous practice lab. You will be able to reuse much of the work you did there to prepare your database tables for executing SQL queries.

# %% [markdown]
# # Understand the datasets
#
# To complete the assignment problems in this notebook you will be using subsetted snapshots of two datasets from Statistics Canada, and one from the Bank of Canada. The links to the prepared datasets are provided in the next section; the interested student can explore the landing pages for the source datasets as follows:
#
# 1.  <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMRP0203ENSkillsNetwork23863830-2021-01-01&pid=3210035901">Canadian Principal Crops (Data & Metadata)</a>
# 2.  <a href="https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMRP0203ENSkillsNetwork23863830-2021-01-01&pid=3210007701">Farm product prices (Data & Metadata)</a>
# 3.  <a href="https://www.bankofcanada.ca/rates/exchange/daily-exchange-rates?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMRP0203ENSkillsNetwork23863830-2021-01-01">Bank of Canada daily average exchange rates</a>
#
# ### 1. Canadian Principal Crops Data \*
#
# This dataset contains agricultural production measures for the principle crops grown in Canada, including a breakdown by province and teritory, for each year from 1908 to 2020.
#
# For this assignment you will use a preprocessed snapshot of this dataset (see below).
#
# A detailed description of this dataset can be obtained from the StatsCan Data Portal at:
# [https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3210035901](https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMRP0203ENSkillsNetwork23863830-2021-01-01&pid=3210035901)\
# Detailed information is included in the metadata file and as header text in the data file, which can be downloaded - look for the 'download options' link.
#
# ### 2. Farm product prices
#
# This dataset contains monthly average farm product prices for Canadian crops and livestock by province and teritory, from 1980 to 2020 (or 'last year', whichever is greatest).
#
# For this assignment you will use a preprocessed snapshot of this dataset (see below).
#
# A description of this dataset can be obtained from the StatsCan Data Portal at:
# [https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3210007701](https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMRP0203ENSkillsNetwork23863830-2021-01-01&pid=3210007701)
# The information is included in the metadata file, which can be downloaded - look for the 'download options' link.
#
# ### 3. Bank of Canada daily average exchange rates \*
#
# This dataset contains the daily average exchange rates for multiple foreign currencies. Exchange rates are expressed as 1 unit of the foreign currency converted into Canadian dollars. It includes only the latest four years of data, and the rates are published once each business day by 16:30 ET.
#
# For this assignment you will use a snapshot of this dataset with only the USD-CAD exchange rates included (see next section). We have also prepared a monthly averaged version which you will be using below.
#
# A brief description of this dataset and the original dataset can be obtained from the Bank of Canada Data Portal at:
# [https://www.bankofcanada.ca/rates/exchange/daily-exchange-rates/](https://www.bankofcanada.ca/rates/exchange/daily-exchange-rates/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMRP0203ENSkillsNetwork23863830-2021-01-01)
#
# ( \* these datasets are the same as the ones you used in the practice lab)

# %% [markdown]
# ### Dataset URLs
#
# 1.  Annual Crop Data: <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Annual_Crop_Data.csv>
#
# 2.  Farm product prices: <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Monthly_Farm_Prices.csv>
#
# 3.  Daily FX Data: <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Daily_FX.csv>
#
# 4.  Monthly FX Data: <https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Monthly_FX.csv>
#
# <span style="color:red">**IMPORTANT:**</span> You will be loading these datasets directly into R data frames from these URLs instead of from the StatsCan and Bank of Canada portals. The versions provided at these URLs are simplified and subsetted versions of the original datasets.

# %% [markdown]
# #### Now let's load these datasets into four separate Db2 tables.
#
# Let's first load the RODBC package:

# %%
library(RODBC)

# %% [markdown]
# ## Problem 1
#
# #### Create tables
#
# Establish a connection to the Db2 database, and create the following four tables using the RODBC package in R.
# Use the separate cells provided below to create each of your tables.
#
# 1.  **CROP_DATA**
# 2.  **FARM_PRICES**
# 3.  **DAILY_FX**
# 4.  **MONTHLY_FX**
#
# The previous practice lab will help you accomplish this.

# %% [markdown]
# ### Solution 1

# %%
# Establish database connection


library(RODBC);
    dsn_driver <- "{IBM DB2 ODBC Driver}"
    dsn_database <- "bludb"            # e.g. "bludb"
    dsn_hostname <- "55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud" # e.g "54a2f15b-5c0f-46df-8954-.databases.appdomain.cloud"
    dsn_port <- "31929"   # e.g. "32733" 
    dsn_protocol <- "TCPIP"            # i.e. "TCPIP"
    dsn_uid <- "wfc40160"        # e.g. "zjh17769"
    dsn_pwd <- "szlaAXcbEvazdUyn"      # e.g. "zcwd4+8gbq9bm5k4"  
    dsn_security <- "ssl"

conn_path=paste("DRIVER=",dsn_driver,
                  ";DATABASE=",dsn_database,
                 ";HOSTNAME=",dsn_hostname,
                  ";PORT=",dsn_port,
                  ";PROTOCOL=",dsn_protocol,
                  ";UID=",dsn_uid,
                 ";PWD=",dsn_pwd,
                  ";SECURITY=",dsn_security,        
                    sep="")
    conn <- odbcDriverConnect(conn_path, believeNRows=FALSE)
    conn
# Out:
# RODBC Connection 1
# Details:
#   case=nochange
#   DRIVER={IBM DB2 ODBC DRIVER}
#   UID=wfc40160
#   PWD=******
#   DATABASE=bludb
#   HOSTNAME=55fbc997-9266-4331-afd3-888b05e734c0.bs2io90l08kqb1od8lcg.databases.appdomain.cloud
#   PORT=31929
#   PROTOCOL=TCPIP
#   SECURITY=SSL

# %%
# CROP_DATA:

df1 <- sqlQuery(conn, 
                    "CREATE TABLE CROP_DATA1 (
                                      CD_ID INTEGER NOT NULL,
                                      YEAR DATE NOT NULL,
                                      CROP_TYPE VARCHAR(20) NOT NULL,
                                      GEO VARCHAR(20) NOT NULL, 
                                      SEEDED_AREA INTEGER NOT NULL,
                                      HARVESTED_AREA INTEGER NOT NULL,
                                      PRODUCTION INTEGER NOT NULL,
                                      AVG_YIELD INTEGER NOT NULL,
                                      PRIMARY KEY (CD_ID)
                                      )", 
                    errors=FALSE
                    )

    if (df1 == -1){
        cat ("An error has occurred.\n")
        msg <- odbcGetErrMsg(conn)
        print (msg)
    } else {
        cat ("Table was created successfully.\n")
    }
# Out:
# Table was created successfully.

# %%
# FARM PRICES1

df1 <- sqlQuery(conn, 
                    "CREATE TABLE FARM_PRICES1 (
                                      CD_ID INTEGER NOT NULL,
                                      YEAR DATE NOT NULL,
                                      CROP_TYPE VARCHAR(20) NOT NULL,
                                      GEO VARCHAR(20) NOT NULL, 
                                      PRICE_PERMT FLOAT(6),
                                      PRIMARY KEY (CD_ID)
                                      )", 
                    errors=FALSE
                    )

    if (df1 == -1){
        cat ("An error has occurred.\n")
        msg <- odbcGetErrMsg(conn)
        print (msg)
    } else {
        cat ("Table was created successfully.\n")
    }
# Out:
# Table was created successfully.

# %%
# DAILY_FX:


df1 <- sqlQuery(conn, 
                    "CREATE TABLE DAILY_FX1 (
                                      DFX_ID INTEGER NOT NULL,
                                      YEAR DATE NOT NULL,
                                      FXUSDCAD FLOAT(6),
                                      PRIMARY KEY (DFX_ID)
                                      )", 
                    errors=FALSE
                    )

    if (df1 == -1){
        cat ("An error has occurred.\n")
        msg <- odbcGetErrMsg(conn)
        print (msg)
    } else {
        cat ("Table was created successfully.\n")
    }
# Out:
# Table was created successfully.

# %%
# MONTHLY_FX1:


df1 <- sqlQuery(conn, 
                    "CREATE TABLE MONTHLY_FX1 (
                                      DFX_ID INTEGER NOT NULL,
                                      YEAR DATE NOT NULL,
                                      FXUSDCAD FLOAT(6),
                                      PRIMARY KEY (DFX_ID)
                                      )", 
                    errors=FALSE
                    )

    if (df1 == -1){
        cat ("An error has occurred.\n")
        msg <- odbcGetErrMsg(conn)
        print (msg)
    } else {
        cat ("Table was created successfully.\n")
    }
# Out:
# Table was created successfully.

# %% [markdown]
# ## Problem 2
#
# #### Read Datasets and Load Tables
#
# Read the datasets into R dataframes using the urls provided above. Then load your tables.

# %% [markdown]
# ### Solution 2

# %%
cropdf=read.csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Annual_Crop_Data.csv', colClasses=c(YEAR="character"))
cropdf; 

farmpricdf=read.csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Monthly_Farm_Prices.csv', colClasses=c(DATE="character"))
farmpricdf; 

dailyfxdf=read.csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-RP0203EN-SkillsNetwork/labs/Final%20Project/Daily_FX.csv', colClasses=c(DATE="character"))
dailyfxdf; 

monthlyfxdf=read.csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM
# 23 22     2018-11-01 1.320038
# 24 23     2018-12-01 1.343184
# 25 24     2019-01-01 1.330100
# 26 25     2019-02-01 1.320558
# 27 26     2019-03-01 1.336819
# 28 27     2019-04-01 1.337771
# 29 28     2019-05-01 1.345905
# 30 29     2019-06-01 1.328730
# 31 30     2019-07-01 1.310105
# 32 31     2019-08-01 1.327748
# 33 32     2019-09-01 1.324050
# 34 33     2019-10-01 1.318977
# 35 34     2019-11-01 1.323880
# 36 35     2019-12-01 1.317170
# 37 36     2020-01-01 1.308673
# 38 37     2020-02-01 1.328584
# 39 38     2020-03-01 1.395250
# 40 39     2020-04-01 1.405786
# 41 40     2020-05-01 1.396970
# 42 41     2020-06-01 1.355032
# 43 42     2020-07-01 1.349850
# 44 43     2020-08-01 1.322205
# 45 44     2020-09-01 1.322810
# 46 45     2020-10-01 1.321471
# 47 46     2020-11-01 1.306820
# 48 47     2020-12-01 1.280771
# 49 48     2021-01-01 1.272405
# 50 49     2021-02-01 1.274462

# %% [markdown]
# ## Now execute SQL queries using the RODBC R package to solve the assignment problems.
#
# ## Problem 3
#
# #### How many records are in the farm prices dataset?

# %% [markdown]
# ### Solution 3

# %%
library(RODBC)
#conn <- odbcDriverConnect(conn_path)
#sqlQuery(conn, "SELECT COUNT(*) FROM farmpricdf")

nrow(farmpricdf)

#Answer 2678
# Out:
# [1] 2678

# %% [markdown]
# ## Problem 4
#
# #### Which geographies are included in the farm prices dataset?

# %% [markdown]
# ### Solution 4

# %%
#SELECT GEO FROM farmpricdf

farmpricdf$GEO

#Answer: Alberta and Saskatchewan
# Out:
#    [1] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#    [6] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [11] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [16] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [21] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [26] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [31] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [36] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [41] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [46] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [51] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [56] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [61] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [66] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [71] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [76] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [81] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [86] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#   [91] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#   [96] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [101] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [106] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [111] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [116] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [121] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [126] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [131] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [136] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [141] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [146] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [151] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [156] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [161] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [166] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [171] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [176] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [181] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [186] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [191] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [196] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [201] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [206] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [211] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [216] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [221] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [226] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [231] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [236] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [241] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [246] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [251] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [256] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [261] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [266] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [271] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [276] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [281] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [286] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [291] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [296] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [301] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [306] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [311] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [316] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [321] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [326] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [331] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [336] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [341] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [346] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [351] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [356] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [361] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [366] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [371] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [376] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [381] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [386] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [391] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [396] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [401] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [406] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [411] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [416] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [421] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [426] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [431] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [436] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [441] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [446] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [451] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [456] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [461] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [466] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [471] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [476] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [481] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [486] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [491] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [496] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [501] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [506] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [511] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [516] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [521] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [526] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [531] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [536] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [541] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [546] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [551] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [556] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [561] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [566] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [571] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [576] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [581] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [586] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [591] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [596] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [601] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [606] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [611] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [616] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [621] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [626] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [631] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [636] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [641] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [646] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [651] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [656] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [661] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [666] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [671] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [676] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [681] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [686] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [691] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [696] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [701] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [706] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [711] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [716] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [721] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [726] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [731] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [736] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [741] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [746] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [751] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [756] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [761] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [766] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [771] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [776] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  [781] Alberta      Saskatchewan Alberta      Saskatchewan Alberta
#  [786] Saskatchewan Alberta      Saskatchewan Alberta      Saskatchewan
#  
#    FROM CROP_DATA
#    WHERE YEAR(YEAR) =1968 AND
#        CROP_TYPE = 'Rye' AND
#            GEO='CANADA';")


query <- "SELECT sum(HARVESTED_AREA), 
        FROM CROP_DATA1
    WHERE YEAR(YEAR) =1968 AND
      CROP_TYPE = 'Rye' AND
   GEO='CANADA';"
view <- sqlQuery(conn,query)
 view
# Out:
# [1] "42601 -104 [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token \"sum(HARVESTED_AREA),          FROM CROP_DATA1     WH\" was found following \"SELECT \".  Expected tokens may include:  \"<PiStart>\".  SQLSTATE=42601\n"
# [2] "[RODBC] ERROR: Could not SQLExecDirect 'SELECT sum(HARVESTED_AREA), \n        FROM CROP_DATA1\n    WHERE YEAR(YEAR) =1968 AND\n      CROP_TYPE = 'Rye' AND\n   GEO='CANADA';'"

# %% [markdown]
# ## Problem 6
#
# #### Query and display the first 6 rows of the farm prices table for Rye.

# %% [markdown]
# ### Solution 6

# %%
#SELECT * from farmpricdf LIMIT 6
#or 
head(farmpricdf)
# Out:
#   CD_ID DATE       CROP_TYPE GEO          PRICE_PRERMT
# 1 0     1985-01-01 Barley    Alberta      127.39
# 2 1     1985-01-01 Barley    Saskatchewan 121.38
# 3 2     1985-01-01 Canola    Alberta      342.00
# 4 3     1985-01-01 Canola    Saskatchewan 339.82
# 5 4     1985-01-01 Rye       Alberta      100.77
# 6 5     1985-01-01 Rye       Saskatchewan 109.75

# %% [markdown]
# ## Problem 7
#
# #### Which provinces grew Barley?

# %% [markdown]
# ### Solution 7

# %%
query <- "SELECT GEO, 
        FROM FARM_PRICE1
    WHERE CROP_TYPE = 'Barley';"
view <- sqlQuery(conn,query)
 view
# Out:
# [1] "42601 -104 [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token \"FARM_PRICE1\" was found following \"T GEO,          FROM\".  Expected tokens may include:  \"FROM\".  SQLSTATE=42601\n"
# [2] "[RODBC] ERROR: Could not SQLExecDirect 'SELECT GEO, \n        FROM FARM_PRICE1\n    WHERE CROP_TYPE = 'Barley';'"

# %% [markdown]
# ## Problem 8
#
# #### Find the first and last dates for the farm prices data.

# %% [markdown]
# ### Solution 8

# %%
#SELECT * from farmpricdf LIMIT 1
#SELECT * from farmpricdf LIMIT -1
#or
head(farmpricdf,n=1)
tail(farmpricdf,n=1)
# Out:
#   CD_ID DATE       CROP_TYPE GEO     PRICE_PRERMT
# 1 0     1985-01-01 Barley    Alberta 127.39
#      CD_ID DATE       CROP_TYPE GEO          PRICE_PRERMT
# 2678 2677  2020-12-01 Wheat     Saskatchewan 271.9

# %% [markdown]
# ## Problem 9
#
# #### Which crops have ever reached a farm price greater than or equal to $350 per metric tonne?

# %% [markdown]
# ### Solution 9

# %%
query <- "SELECT CROP_TYPE, 
        FROM FARM_PRICE1
    WHERE PRICE_PRERMT >= 350;"
view <- sqlQuery(conn,query)
 view
# Out:
# [1] "42601 -104 [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token \"FARM_PRICE1\" was found following \"_TYPE,          FROM\".  Expected tokens may include:  \"FROM\".  SQLSTATE=42601\n"
# [2] "[RODBC] ERROR: Could not SQLExecDirect 'SELECT CROP_TYPE, \n        FROM FARM_PRICE1\n    WHERE PRICE_PRERMT >= 350;'"

# %% [markdown]
# ## Problem 10
#
# #### Rank the crop types harvested in Saskatchewan in the year 2000 by their average yield. Which crop performed best?

# %% [markdown]
# ### Solution 10

# %%
query <- "SELECT CROP_TYPE, 
        FROM FARM_PRICE1
    WHERE YEAR(YEAR)=2000 AND
GEO='Saskatchewan'
ORDER BY AVG_YIELD;"
view <- sqlQuery(conn,query)
 view
# Out:
# [1] "42601 -104 [IBM][CLI Driver][DB2/LINUXX8664] SQL0104N  An unexpected token \"CROP_TYPE,          FROM FARM_PRICE1     WHERE YEAR(\" was found following \"SELECT \".  Expected tokens may include:  \"<PiStart>\".  SQLSTATE=42601\n"
# [2] "[RODBC] ERROR: Could not SQLExecDirect 'SELECT CROP_TYPE, \n        FROM FARM_PRICE1\n    WHERE YEAR(YEAR)=2000 AND\nGEO='Saskatchewan'\nORDER BY AVG_YIELD;'"

# %% [markdown]
# ## Problem 11
#
# #### Rank the crops and geographies by their average yield (KG per hectare) since the year 2000. Which crop and province had the highest average yield since the year 2000?

# %% [markdown]
# ### Solution 11

# %% [markdown]
# ## Problem 12
#
# #### Use a subquery to determine how much wheat was harvested in Canada in the most recent year of the data.

# %% [markdown]
# ### Solution 12

# %% [markdown]
# ## Problem 13
#
# #### Use an implicit inner join to calculate the monthly price per metric tonne of Canola grown in Saskatchewan in both Canadian and US dollars. Display the most recent 6 months of the data.

# %% [markdown]
# ### Solution 13

# %% [raw]
# query <- "SELECT * FROM MONTHLY_FX
# INNER JOIN
# SELECT * FROM
#
# ;"
# view <- sqlQuery(conn,query)
#  view

# %% [raw]
# ## Author(s)
#
# <h4> Jeff Grossman </h4>
#
# ## Contributor(s)
#
# <h4> Rav Ahuja </h4>
#
# ## Change log
#
# | Date       | Version | Changed by    | Change Description                                                                                         |
# | ---------- | ------- | ------------- | ---------------------------------------------------------------------------------------------------------- |
# | 2021-04-01 | 0.7     | Jeff Grossman | Split Problem 1 solution cell into multiple cells, fixed minor bugs                                        |
# | 2021-03-12 | 0.6     | Jeff Grossman | Cleaned up content for production                                                                          |
# | 2021-03-11 | 0.5     | Jeff Grossman | Moved more advanced problems to optional honours module                                                    |
# | 2021-03-10 | 0.4     | Jeff Grossman | Added introductory and intermediate level problems and removed some advanced problems                      |
# | 2021-03-04 | 0.3     | Jeff Grossman | Moved some problems to a new practice lab as prep for this assignment                                      |
# | 2021-03-04 | 0.2     | Jeff Grossman | Sorted problems roughly by level of difficulty and relegated more advanced ones to ungraded bonus problems |
# | 2021-02-20 | 0.1     | Jeff Grossman | Started content creation                                                                                   |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
